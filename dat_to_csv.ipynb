# %%
import pandas as pd

# %%
df0 = pd.read_csv('output/KIN_gS_pert_2_perturbations_k0_s.dat',sep="\s+", 
                 skiprows=2,
                #usecols=[1,15],
                names = ['1:tau', '2:a', '3:delta_g', '4:theta_g', '5:shear_g',
       '6:pol0_g', '7:pol1_g', '8:pol2_g', '9:delta_b', '10:theta_b', '11:psi',
       '12:phi', '13:delta_ur', '14:theta_ur', '15:shear_ur', '16:delta_cdm',
       '17:theta_cdm', '18:delta_rho_fld', '19:rho_plus_p_theta_fld',
       '20:delta_p_fld'])
df1 = pd.read_csv('output/KIN_gS_pert_2_perturbations_k1_s.dat',sep="\s+", 
                 skiprows=2,
                #usecols=[1,15],
                names = ['1:tau', '2:a', '3:delta_g', '4:theta_g', '5:shear_g',
       '6:pol0_g', '7:pol1_g', '8:pol2_g', '9:delta_b', '10:theta_b', '11:psi',
       '12:phi', '13:delta_ur', '14:theta_ur', '15:shear_ur', '16:delta_cdm',
       '17:theta_cdm', '18:delta_rho_fld', '19:rho_plus_p_theta_fld',
       '20:delta_p_fld'])
df2 = pd.read_csv('output/KIN_gS_pert_2_perturbations_k2_s.dat',sep="\s+", 
                 skiprows=2,
                #usecols=[1,15],
                names = ['1:tau', '2:a', '3:delta_g', '4:theta_g', '5:shear_g',
       '6:pol0_g', '7:pol1_g', '8:pol2_g', '9:delta_b', '10:theta_b', '11:psi',
       '12:phi', '13:delta_ur', '14:theta_ur', '15:shear_ur', '16:delta_cdm',
       '17:theta_cdm', '18:delta_rho_fld', '19:rho_plus_p_theta_fld',
       '20:delta_p_fld'])

# %%
df0.head()
# Out:
#       1:tau           2:a  3:delta_g  4:theta_g     5:shear_g      6:pol0_g  \
# 0  0.102049  4.061132e-07  -0.003471   -0.00003 -1.369653e-08 -3.424133e-08
# 1  0.102049  4.061133e-07  -0.003471   -0.00003 -1.369653e-08 -3.424133e-08
# 2  0.102049  4.061133e-07  -0.003471   -0.00003 -1.369653e-08 -3.424133e-08
# 3  0.102049  4.061138e-07  -0.003471   -0.00003 -1.369652e-08 -3.424130e-08
# 4  0.102049  4.061143e-07  -0.003471   -0.00003 -1.369651e-08 -3.424127e-08
#
#        7:pol1_g      8:pol2_g  9:delta_b  10:theta_b    11:psi    12:phi  \
# 0 -2.458201e-15 -6.848266e-09  -0.002603    -0.00003  2.503419  2.532315
# 1 -2.458202e-15 -6.848266e-09  -0.002603    -0.00003  2.503418  2.532315
# 2 -2.458202e-15 -6.848265e-09  -0.002603    -0.00003  2.503418  2.532314
# 3 -2.458206e-15 -6.848260e-09  -0.002603    -0.00003  2.503412  2.532308
# 4 -2.458211e-15 -6.848254e-09  -0.002603    -0.00003  2.503405  2.532302
#
# ...

# %%
df0_cdm = df0[['2:a','16:delta_cdm']]
df1_cdm = df1[['2:a','16:delta_cdm']]
df2_cdm = df2[['2:a','16:delta_cdm']]

# %%
df0_cdm.to_csv('output/KIN_gs_pert2_k1.csv',index=False)
df1_cdm.to_csv('output/KIN_gs_pert2_k10.csv',index=False)
df2_cdm.to_csv('output/KIN_gs_pert2_k100.csv',index=False)
